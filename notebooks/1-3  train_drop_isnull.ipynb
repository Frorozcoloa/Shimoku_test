# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import os
from sklearn.model_selection import train_test_split

from mlflow import set_tracking_uri
set_tracking_uri('http://127.0.0.1:8084')

# %%
integrated = pd.read_csv('../datasets/processed/integrated.csv')
print(integrated.shape)
integrated = integrated.drop_duplicates()
columns_has_null = [column for column in integrated.columns if "isnull" in column]
integrated = integrated.drop(columns_has_null, axis=1)
# Out:
# (5605, 15)

# %%
df_train, df_test = train_test_split(integrated, test_size=0.3, random_state=42, stratify=integrated['status'])

# %%
bool_cols = df_train.columns[df_train.dtypes == bool].tolist()
numerical_cols = df_train.columns[df_train.dtypes == float].tolist()
categorical_cols = df_train.columns[df_train.dtypes == object].tolist()
categorical_cols.remove('status')
print(bool_cols)
print(numerical_cols)
print(categorical_cols)
categorical_uses = ['pain', 'lead_source']
# Out:
# ['has_discount_code', 'was_corporate_event', 'pain']
# ['price', 'duration_created']
# ['lead_has_city', 'lead_has_acquisition_campaign', 'lead_source']

# %%
from sklearn.metrics import classification_report
import mlflow
import mlflow.sklearn
from pycaret.classification import *

# %%
from sklearn.preprocessing import LabelEncoder
le_pre = LabelEncoder()
df_train['status'] = le_pre.fit_transform(df_train['status'])
df_test['status'] = le_pre.transform(df_test['status'])

for col in categorical_cols:
    print(col)
    try:
        df_train[col] = le_pre.fit_transform(df_train[col])
        df_test[col] = le_pre.transform(df_test[col])
    except:
        continue
# Out:
# lead_has_city
# lead_has_acquisition_campaign
# lead_source

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import mlflow
from pycaret.classification import *

def save_best_model_with_mlflow(model):
    # Guardar el modelo en MLflow
    mlflow.sklearn.log_model(model, "best_model")

# Configuración inicial de PyCaret
clf1 = setup(df_train, target='status', session_id=421,
             numeric_features=numerical_cols,
             categorical_features=categorical_cols + bool_cols,
             log_experiment=True,
             experiment_name='pycaret-mlflow-demo',
             )


best_model = compare_models(sort='AUC')

# Realizar la sintonización de hiperparámetros
tuned_model = tune_model(best_model, optimize='AUC')

# Guardar el mejor modelo y métricas en MLflow

mlflow.log_params(params=tuned_model.get_params())


# Guardar el mejor modelo en MLflow
save_best_model_with_mlflow(tuned_model)
# Out:
# <style type="text/css">
# #T_a7906_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a7906">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7906_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a7906_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7906_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7906_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a7906_row0_col1" class="data row0 col1" >421</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7906_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a7906_row1_col1" class="data row1 col1" >status</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7906_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a7906_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7906_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a7906_row3_col1" class="data row3 col1" >(2986, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7906_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a7906_row4_col1" class="data row4 col1" >(2986, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7906_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a7906_row5_col1" class="data row5 col1" >(2090, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a7906_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a7906_row6_col1" class="data row6 col1" >(896, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a7906_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_a7906_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a7906_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_a7906_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a7906_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_a7906_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a7906_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_a7906_row10_col1" class="data row10 col1" >27.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a7906_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_a7906_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a7906_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_a7906_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a7906_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_a7906_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a7906_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_a7906_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a7906_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_a7906_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a7906_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_a7906_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a7906_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_a7906_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a7906_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_a7906_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a7906_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_a7906_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a7906_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_a7906_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a7906_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_a7906_row21_col1" class="data row21 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a7906_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_a7906_row22_col1" class="data row22 col1" >pycaret-mlflow-demo</td>
#     </tr>
#     <tr>
#       <th id="T_a7906_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a7906_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_a7906_row23_col1" class="data row23 col1" >42e4</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bed36 th {
#   text-align: left;
# }
# #T_bed36_row0_col0, #T_bed36_row0_col3, #T_bed36_row0_col5, #T_bed36_row0_col6, #T_bed36_row1_col0, #T_bed36_row1_col2, #T_bed36_row1_col3, #T_bed36_row1_col4, #T_bed36_row1_col7, #T_bed36_row2_col0, #T_bed36_row2_col1, #T_bed36_row2_col2, #T_bed36_row2_col3, #T_bed36_row2_col4, #T_bed36_row2_col5, #T_bed36_row2_col6, #T_bed36_row2_col7, #T_bed36_row3_col0, #T_bed36_row3_col1, #T_bed36_row3_col2, #T_bed36_row3_col3, #T_bed36_row3_col4, #T_bed36_row3_col5, #T_bed36_row3_col6, #T_bed36_row3_col7, #T_bed36_row4_col0, #T_bed36_row4_col1, #T_bed36_row4_col2, #T_bed36_row4_col3, #T_bed36_row4_col4, #T_bed36_row4_col5, #T_bed36_row4_col6, #T_bed36_row4_col7, #T_bed36_row5_col0, #T_bed36_row5_col1, #T_bed36_row5_col2, #T_bed36_row5_col3, #T_bed36_row5_col4, #T_bed36_row5_col5, #T_bed36_row5_col6, #T_bed36_row5_col7, #T_bed36_row6_col0, #T_bed36_row6_col1, #T_bed36_row6_col2, #T_bed36_row6_col4, #T_bed36_row6_col5, #T_bed36_row6_col6, #T_bed36_row6_col7, #T_bed36_row7_col0, #T_bed36_row7_col1, #T_bed36_row7_col2, #T_bed36_row7_col3, #T_bed36_row7_col4, #T_bed36_row7_col5, #T_bed36_row7_col6, #T_bed36_row7_col7, #T_bed36_row8_col0, #T_bed36_row8_col1, #T_bed36_row8_col2, #T_bed36_row8_col3, #T_bed36_row8_col4, #T_bed36_row8_col5, #T_bed36_row8_col6, #T_bed36_row8_col7, #T_bed36_row9_col0, #T_bed36_row9_col1, #T_bed36_row9_col2, #T_bed36_row9_col3, #T_bed36_row9_col4, #T_bed36_row9_col5, #T_bed36_row9_col6, #T_bed36_row9_col7, #T_bed36_row10_col0, #T_bed36_row10_col1, #T_bed36_row10_col2, #T_bed36_row10_col3, #T_bed36_row10_col4, #T_bed36_row10_col5, #T_bed36_row10_col6, #T_bed36_row10_col7, #T_bed36_row11_col0, #T_bed36_row11_col1, #T_bed36_row11_col2, #T_bed36_row11_col3, #T_bed36_row11_col4, #T_bed36_row11_col5, #T_bed36_row11_col6, #T_bed36_row11_col7, #T_bed36_row12_col0, #T_bed36_row12_col1, #T_bed36_row12_col2, #T_bed36_row12_col3, #T_bed36_row12_col4, #T_bed36_row12_col5, #T_bed36_row12_col6, #T_bed36_row12_col7, #T_bed36_row13_col0, #T_bed36_row13_col1, #T_bed36_row13_col2, #T_bed36_row13_col3, #T_bed36_row13_col4, #T_bed36_row13_col5, #T_bed36_row13_col6, #T_bed36_row13_col7, #T_bed36_row14_col0, #T_bed36_row14_col1, #T_bed36_row14_col2, #T_bed36_row14_col4, #T_bed36_row14_col5, #T_bed36_row14_col6, #T_bed36_row14_col7 {
#   text-align: left;
# }
# #T_bed36_row0_col1, #T_bed36_row0_col2, #T_bed36_row0_col4, #T_bed36_row0_col7, #T_bed36_row1_col1, #T_bed36_row1_col5, #T_bed36_row1_col6, #T_bed36_row6_col3, #T_bed36_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bed36_row0_col8, #T_bed36_row1_col8, #T_bed36_row2_col8, #T_bed36_row3_col8, #T_bed36_row4_col8, #T_bed36_row5_col8, #T_bed36_row6_col8, #T_bed36_row7_col8, #T_bed36_row8_col8, #T_bed36_row9_col8, #T_bed36_row10_col8, #T_bed36_row11_col8, #T_bed36_row13_col8, #T_bed36_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bed36_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bed36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bed36_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bed36_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bed36_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bed36_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bed36_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bed36_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bed36_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bed36_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bed36_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bed36_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_bed36_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_bed36_row0_col1" class="data row0 col1" >0.7761</td>
#       <td id="T_bed36_row0_col2" class="data row0 col2" >0.8675</td>
#       <td id="T_bed36_row0_col3" class="data row0 col3" >0.7738</td>
#       <td id="T_bed36_row0_col4" class="data row0 col4" >0.7738</td>
#       <td id="T_bed36_row0_col5" class="data row0 col5" >0.7730</td>
#       <td id="T_bed36_row0_col6" class="data row0 col6" >0.5521</td>
#       <td id="T_bed36_row0_col7" class="data row0 col7" >0.5532</td>
#       <td id="T_bed36_row0_col8" class="data row0 col8" >0.1000</td>
#     </tr>
#     <tr>
#       <th id="T_bed36_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_bed36_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bed36_row1_col1" class="data row1 col1" >0.7761</td>
#       <td id="T_bed36_row1_col2" class="data row1 col2" >0.8639</td>
#       <td id="T_bed36_row1_col3" class="data row1 col3" >0.7845</td>
#       <td id="T_bed36_row1_col4" class="data row1 col4" >0.7671</td>
#       <td id="T_bed36_row1_col5" class="data row1 col5" >0.7753</td>
#       <td id="T_bed36_row1_col6" class="data row1 col6" >0.5522</td>
#       <td id="T_bed36_row1_col7" class="data row1 col7" >0.5530</td>
#       <td id="T_bed36_row1_col8" class="data row1 col8" >0.0970</td>
#     </tr>
#     <tr>
#       <th id="T_bed36_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_bed36_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_bed36_row2_col1" class="data row2 col1" >0.7699</td>
#       <td id="T_bed36_row2_col2" class="data row2 col2" >0.8532</td>
#       <td id="T_bed36_row2_col3" class="data row2 col3" >0.7845</td>
#       <td id="T_bed36_row2_col4" class="data row2 col4" >0.7586</td>
#       <td id="T_bed36_row2_col5" class="data row2 col5" >0.7707</td>
#       <td id="T_bed36_row2_col6" class="data row2 col6" >0.5399</td>
#       <td id="T_bed36_row2_col7" class="data row2 col7" >0.5411</td>
#       <td id="T_bed36_row2_col8" class="data row2 col8" >0.0870</td>
#     </tr>
#     <tr>
#       <th id="T_bed36_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_bed36_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_bed36_row3_col1" class="data row3 col1" >0.7593</td>
#       <td id="T_bed36_row3_col2" class="data row3 col2" >0.8518</td>
#       <td id="T_bed36_row3_col3" class="data row3 col3" >0.7670</td>
#       <td id="T_bed36_row3_col4" class="data row3 col4" >0.7518</td>
#       <td id="T_bed36_row3_col5" class="data row3 col5" >0.7585</td>
#       <td id="T_bed36_row3_col6" class="data row3 col6" >0.5187</td>
#       <td id="T_bed36_row3_col7" class="data row3 col7" >0.5200</td>
#       <td id="T_bed36_row3_col8" class="data row3 col8" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_bed36_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_bed36_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_bed36_row4_col1" class="data row4 col1" >0.7455</td>
#       <td id="T_bed36_row4_col2" class="data row4 col2" >0.8309</td>
#       <td id="T_bed36_row4_col3" class="data row4 col3" >0.7680</td>
#       <td id="T_bed36_row4_col4" class="data row4 col4" >0.7305</td>
#       <td id="T_bed36_row4_col5" class="data row4 col5" >0.7483</td>
#       <td id="T_bed36_row4_col6" class="data row4 col6" >0.4912</td>
#       <td id="T_bed36_row4_col7" class="data row4 col7" >0.4924</td>
#       <td id="T_bed36_row4_col8" class="data row4 col8" >0.1290</td>
#     </tr>
#     <tr>
#       <th id="T_bed36_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_bed36_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_bed36_row5_col1" class="data row5 col1" >0.7211</td>
#       <td id="T_bed36_row5_col2" class="data row5 col2" >0.7778</td>
#       <td id="T_bed36_row5_col3" class="data row5 col3" >0.7515</td>
#       <td id="T_bed36_row5_col4" class="data row5 col4" >0.7047</td>
#       <td id=
# <style type="text/css">
# #T_2f6cd_row10_col0, #T_2f6cd_row10_col1, #T_2f6cd_row10_col2, #T_2f6cd_row10_col3, #T_2f6cd_row10_col4, #T_2f6cd_row10_col5, #T_2f6cd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2f6cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f6cd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2f6cd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2f6cd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2f6cd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2f6cd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2f6cd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2f6cd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f6cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f6cd_row0_col0" class="data row0 col0" >0.7512</td>
#       <td id="T_2f6cd_row0_col1" class="data row0 col1" >0.8805</td>
#       <td id="T_2f6cd_row0_col2" class="data row0 col2" >0.5340</td>
#       <td id="T_2f6cd_row0_col3" class="data row0 col3" >0.9322</td>
#       <td id="T_2f6cd_row0_col4" class="data row0 col4" >0.6790</td>
#       <td id="T_2f6cd_row0_col5" class="data row0 col5" >0.4993</td>
#       <td id="T_2f6cd_row0_col6" class="data row0 col6" >0.5512</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f6cd_row1_col0" class="data row1 col0" >0.7321</td>
#       <td id="T_2f6cd_row1_col1" class="data row1 col1" >0.8549</td>
#       <td id="T_2f6cd_row1_col2" class="data row1 col2" >0.5437</td>
#       <td id="T_2f6cd_row1_col3" class="data row1 col3" >0.8615</td>
#       <td id="T_2f6cd_row1_col4" class="data row1 col4" >0.6667</td>
#       <td id="T_2f6cd_row1_col5" class="data row1 col5" >0.4612</td>
#       <td id="T_2f6cd_row1_col6" class="data row1 col6" >0.4955</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f6cd_row2_col0" class="data row2 col0" >0.7177</td>
#       <td id="T_2f6cd_row2_col1" class="data row2 col1" >0.8814</td>
#       <td id="T_2f6cd_row2_col2" class="data row2 col2" >0.5049</td>
#       <td id="T_2f6cd_row2_col3" class="data row2 col3" >0.8667</td>
#       <td id="T_2f6cd_row2_col4" class="data row2 col4" >0.6380</td>
#       <td id="T_2f6cd_row2_col5" class="data row2 col5" >0.4319</td>
#       <td id="T_2f6cd_row2_col6" class="data row2 col6" >0.4745</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f6cd_row3_col0" class="data row3 col0" >0.7225</td>
#       <td id="T_2f6cd_row3_col1" class="data row3 col1" >0.8589</td>
#       <td id="T_2f6cd_row3_col2" class="data row3 col2" >0.5437</td>
#       <td id="T_2f6cd_row3_col3" class="data row3 col3" >0.8358</td>
#       <td id="T_2f6cd_row3_col4" class="data row3 col4" >0.6588</td>
#       <td id="T_2f6cd_row3_col5" class="data row3 col5" >0.4421</td>
#       <td id="T_2f6cd_row3_col6" class="data row3 col6" >0.4713</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f6cd_row4_col0" class="data row4 col0" >0.7129</td>
#       <td id="T_2f6cd_row4_col1" class="data row4 col1" >0.8586</td>
#       <td id="T_2f6cd_row4_col2" class="data row4 col2" >0.4757</td>
#       <td id="T_2f6cd_row4_col3" class="data row4 col3" >0.8909</td>
#       <td id="T_2f6cd_row4_col4" class="data row4 col4" >0.6203</td>
#       <td id="T_2f6cd_row4_col5" class="data row4 col5" >0.4219</td>
#       <td id="T_2f6cd_row4_col6" class="data row4 col6" >0.4759</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f6cd_row5_col0" class="data row5 col0" >0.7464</td>
#       <td id="T_2f6cd_row5_col1" class="data row5 col1" >0.8838</td>
#       <td id="T_2f6cd_row5_col2" class="data row5 col2" >0.5340</td>
#       <td id="T_2f6cd_row5_col3" class="data row5 col3" >0.9167</td>
#       <td id="T_2f6cd_row5_col4" class="data row5 col4" >0.6748</td>
#       <td id="T_2f6cd_row5_col5" class="data row5 col5" >0.4897</td>
#       <td id="T_2f6cd_row5_col6" class="data row5 col6" >0.5380</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f6cd_row6_col0" class="data row6 col0" >0.7703</td>
#       <td id="T_2f6cd_row6_col1" class="data row6 col1" >0.9027</td>
#       <td id="T_2f6cd_row6_col2" class="data row6 col2" >0.5825</td>
#       <td id="T_2f6cd_row6_col3" class="data row6 col3" >0.9231</td>
#       <td id="T_2f6cd_row6_col4" class="data row6 col4" >0.7143</td>
#       <td id="T_2f6cd_row6_col5" class="data row6 col5" >0.5382</td>
#       <td id="T_2f6cd_row6_col6" class="data row6 col6" >0.5782</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2f6cd_row7_col0" class="data row7 col0" >0.7512</td>
#       <td id="T_2f6cd_row7_col1" class="data row7 col1" >0.8689</td>
#       <td id="T_2f6cd_row7_col2" class="data row7 col2" >0.5631</td>
#       <td id="T_2f6cd_row7_col3" class="data row7 col3" >0.8923</td>
#       <td id="T_2f6cd_row7_col4" class="data row7 col4" >0.6905</td>
#       <td id="T_2f6cd_row7_col5" class="data row7 col5" >0.4997</td>
#       <td id="T_2f6cd_row7_col6" class="data row7 col6" >0.5368</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2f6cd_row8_col0" class="data row8 col0" >0.7129</td>
#       <td id="T_2f6cd_row8_col1" class="data row8 col1" >0.8459</td>
#       <td id="T_2f6cd_row8_col2" class="data row8 col2" >0.5049</td>
#       <td id="T_2f6cd_row8_col3" class="data row8 col3" >0.8525</td>
#       <td id="T_2f6cd_row8_col4" class="data row8 col4" >0.6341</td>
#       <td id="T_2f6cd_row8_col5" class="data row8 col5" >0.4224</td>
#       <td id="T_2f6cd_row8_col6" class="data row8 col6" >0.4618</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2f6cd_row9_col0" class="data row9 col0" >0.7081</td>
#       <td id="T_2f6cd_row9_col1" class="data row9 col1" >0.8540</td>
#       <td id="T_2f6cd_row9_col2" class="data row9 col2" >0.5146</td>
#       <td id="T_2f6cd_row9_col3" class="data row9 col3" >0.8281</td>
#       <td id="T_2f6cd_row9_col4" class="data row9 col4" >0.6347</td>
#       <td id="T_2f6cd_row9_col5" class="data row9 col5" >0.4130</td>
#       <td id="T_2f6cd_row9_col6" class="data row9 col6" >0.4456</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2f6cd_row10_col0" class="data row10 col0" >0.7325</td>
#       <td id="T_2f6cd_row10_col1" class="data row10 col1" >0.8690</td>
#       <td id="T_2f6cd_row10_col2" class="data row10 col2" >0.5301</td>
#       <td id="T_2f6cd_row10_col3" class="data row10 col3" >0.8800</td>
#       <td id="T_2f6cd_row10_col4" class="data row10 col4" >0.6611</td>
#       <td id="T_2f6cd_row10_col5" class="data row10 col5" >0.4619</td>
#       <td id="T_2f6cd_row10_col6" class="data row10 col6" >0.5029</td>
#     </tr>
#     <tr>
#       <th id="T_2f6cd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2f6cd_row11_col0" class="data row11 col0" >0.0200</td>
#       <td id="T_2f6cd_row11_col1" class="data row11 col1" >0.0168</td>
#       <td id="T_2f6cd_row11_col2" class="data row11 col2" >0.0295</td>
#       <td id="T_2f6cd_row11_col3" class="data row11 col3" >0.0348</td>
#       <td id="T_2f6cd_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
plot_names = [
        'auc', 'pr', 'confusion_matrix', 'feature', 'error',
        'class_report', 'boundary', 'learning', 'vc',
        'dimension', 'calibration', 'manifold'
    ]
for plot_name in plot_names:

    plot = plot_model(tuned_model, plot=plot_name)

# %%
proba_pred = predict_model(tuned_model, df_test, raw_score=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9777c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9777c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9777c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9777c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9777c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9777c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9777c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9777c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9777c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9777c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9777c_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9777c_row0_col1" class="data row0 col1" >0.7947</td>
#       <td id="T_9777c_row0_col2" class="data row0 col2" >0.8921</td>
#       <td id="T_9777c_row0_col3" class="data row0 col3" >0.8070</td>
#       <td id="T_9777c_row0_col4" class="data row0 col4" >0.7834</td>
#       <td id="T_9777c_row0_col5" class="data row0 col5" >0.7950</td>
#       <td id="T_9777c_row0_col6" class="data row0 col6" >0.5895</td>
#       <td id="T_9777c_row0_col7" class="data row0 col7" >0.5897</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.metrics import classification_report

def metrics(y_true, y_pred):
    cr = classification_report(y_true, y_pred, output_dict  =True)
    mlflow.log_metric("accuracy", cr.pop("accuracy"))
    for class_or_avg, metrics_dict in cr.items():
        for metric, value in metrics_dict.items():
            mlflow.log_metric(class_or_avg + '_' + metric,value)
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
def plot_roc_curve(y_true, y_pred):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    mlflow.log_metric('roc_auc', roc_auc)
    plt.plot(fpr, tpr, color='darkorange', lw=2,
             label='ROC curve (area = %0.2f)' % roc_auc)
    plt.legend(loc="lower right")
    plt.show()

metrics(proba_pred['status'], proba_pred['prediction_label'])
print(classification_report(proba_pred['status'], proba_pred['prediction_label']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       649
#            1       0.78      0.81      0.80       632
#
#     accuracy                           0.79      1281
#    macro avg       0.79      0.79      0.79      1281
# weighted avg       0.80      0.79      0.79      1281

# %%
plot_roc_curve(proba_pred['status'], proba_pred['prediction_score_1'])
